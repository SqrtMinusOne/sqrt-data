# %%
import pandas as pd
import numpy as np
from IPython.display import display
from datetime import timedelta
from urllib.parse import urlparse, parse_qs
import re

# %%
df = pd.read_json('_data.json')
df = df.drop(['products', 'details'], axis=1)
df.time = pd.to_datetime(df.time)
df
# Out:
#                                                   header  \
# 0                                            Launcher 10
# 1      Readably - RSS | Feedbin, Inoreader and Fever API
# 2      Readably - RSS | Feedbin, Inoreader and Fever API
# 3                                            Launcher 10
# 4                        VK — live chatting & free calls
# ...                                                  ...
# 57649                 ivi - фильмы, сериалы, мультфильмы
# 57650                 ivi - фильмы, сериалы, мультфильмы
# 57651                 ivi - фильмы, сериалы, мультфильмы
# 57652                 ivi - фильмы, сериалы, мультфильмы
# 57653                 ivi - фильмы, сериалы, мультфильмы
#
#                                                    title  \
# 0                                       Used Launcher 10
# 1      Used Readably - RSS | Feedbin, Inoreader and F...
# 2      Used Readably - RSS | Feedbin, Inoreader and F...
# 3                                       Used Launcher 10
# 4                   Used VK — live chatting & free calls
# ...                                                  ...
# 57649                               Viewed Ледяной шторм
# 57650                              Viewed Последние часы
# 57651  Viewed Звездные войны: Пробуждение силы (Бонус...
# 57652                           Viewed Игра на понижение
# 57653                         Viewed Тор 2: Царство тьмы
#
#                                                 titleUrl  \
# 0      https://play.google.com/store/apps/details?id=...
# 1      https://play.google.com/store/apps/details?id=...
# 2      https://play.google.com/store/apps/details?id=...
# 3      https://play.google.com/store/apps/details?id=...
# 4      https://play.google.com/store/apps/details?id=...
# ...                                                  ...
# 57649  https://www.google.com/url?q=http://www.ivi.ru...
# 57650  https://www.google.com/url?q=http://www.ivi.ru...
# 57651  https://www.google.com/url?q=http://www.ivi.ru...
# 57652  https://www.google.com/url?q=http://www.ivi.ru...
# 57653  https://www.google.com/url?q=http://www.ivi.ru...
#
#                                   time
# 0     2020-11-02 08:02:47.171000+00:00
# 1     2020-11-02 08:02:43.505000+00:00
# 2     2020-11-02 05:07:25.396000+00:00
# 3     2020-11-02 05:07:22.160000+00:00
# 4     2020-11-02 05:07:11.265000+00:00
# ...                                ...
# 57649 2016-04-22 05:00:08.248000+00:00
# 57650 2016-04-22 05:00:07.744000+00:00
# 57651 2016-04-22 05:00:07.744000+00:00
# 57652 2016-04-22 05:00:07.744000+00:00
# 57653 2015-10-02 19:27:22.190000+00:00
#
# [57654 rows x 4 columns]

# %%
def fix_time(time):
    # TODO
    time = time + timedelta(hours=3)
    return time

df.time = df.time.apply(fix_time)
df
# Out:
#                                                   header  \
# 0                                            Launcher 10
# 1      Readably - RSS | Feedbin, Inoreader and Fever API
# 2      Readably - RSS | Feedbin, Inoreader and Fever API
# 3                                            Launcher 10
# 4                        VK — live chatting & free calls
# ...                                                  ...
# 57649                 ivi - фильмы, сериалы, мультфильмы
# 57650                 ivi - фильмы, сериалы, мультфильмы
# 57651                 ivi - фильмы, сериалы, мультфильмы
# 57652                 ivi - фильмы, сериалы, мультфильмы
# 57653                 ivi - фильмы, сериалы, мультфильмы
#
#                                                    title  \
# 0                                       Used Launcher 10
# 1      Used Readably - RSS | Feedbin, Inoreader and F...
# 2      Used Readably - RSS | Feedbin, Inoreader and F...
# 3                                       Used Launcher 10
# 4                   Used VK — live chatting & free calls
# ...                                                  ...
# 57649                               Viewed Ледяной шторм
# 57650                              Viewed Последние часы
# 57651  Viewed Звездные войны: Пробуждение силы (Бонус...
# 57652                           Viewed Игра на понижение
# 57653                         Viewed Тор 2: Царство тьмы
#
#                                                 titleUrl  \
# 0      https://play.google.com/store/apps/details?id=...
# 1      https://play.google.com/store/apps/details?id=...
# 2      https://play.google.com/store/apps/details?id=...
# 3      https://play.google.com/store/apps/details?id=...
# 4      https://play.google.com/store/apps/details?id=...
# ...                                                  ...
# 57649  https://www.google.com/url?q=http://www.ivi.ru...
# 57650  https://www.google.com/url?q=http://www.ivi.ru...
# 57651  https://www.google.com/url?q=http://www.ivi.ru...
# 57652  https://www.google.com/url?q=http://www.ivi.ru...
# 57653  https://www.google.com/url?q=http://www.ivi.ru...
#
#                                   time
# 0     2020-11-02 11:02:47.171000+00:00
# 1     2020-11-02 11:02:43.505000+00:00
# 2     2020-11-02 08:07:25.396000+00:00
# 3     2020-11-02 08:07:22.160000+00:00
# 4     2020-11-02 08:07:11.265000+00:00
# ...                                ...
# 57649 2016-04-22 08:00:08.248000+00:00
# 57650 2016-04-22 08:00:07.744000+00:00
# 57651 2016-04-22 08:00:07.744000+00:00
# 57652 2016-04-22 08:00:07.744000+00:00
# 57653 2015-10-02 22:27:22.190000+00:00
#
# [57654 rows x 4 columns]

# %%
def get_app_id(datum):
    try:
        if pd.notna(datum['titleUrl']):
            q = parse_qs(urlparse(datum['titleUrl']).query)
            return q['id'][0]
    except KeyError:
        pass
    try:
        if datum['title'].startswith('Used'):
            return ' '.join(datum['title'].split(' ')[1:])
    except KeyError:
        pass
    return datum['header']

df['app_id'] = df.apply(get_app_id, axis=1)

# %%
def fix_name(name):
    if name.startswith('com.'):
        tokens = name.split('.')
        return ' '.join([t[0].upper() + t[1:] for t in tokens[1:]])
    name = re.sub(r'(:|-|—|–).*$', '', name)
    name = re.sub(r'\(.*\)', '', name)
    name = name.strip()
    return name
app_names = {app_name: fix_name(group.iloc[0]['header']) for app_name, group in df.groupby('app_id')}

# for app_name in app_names.values():
#     print(app_name)

df['app_name'] = df.app_id.apply(lambda id_: app_names[id_])

# %%
def align_time(time):
    time = time.replace(minute=time.minute // 30 * 30, second=0, microsecond=0)
    return time
    
df.time = df.time.apply(align_time)

# %%
dfg = df.groupby(['app_name', 'time']) \
    .agg(lambda x: x.iloc[0]) \
    .reset_index() \
    .sort_values('time', ascending=False) \
    .reset_index(drop=True)
dfg = dfg.drop(['title', 'titleUrl'], axis=1)
dfg
# Out:
#               app_name                      time  \
# 0          Launcher 10 2020-11-02 11:00:00+00:00
# 1             Readably 2020-11-02 11:00:00+00:00
# 2                   VK 2020-11-02 08:00:00+00:00
# 3             Readably 2020-11-02 08:00:00+00:00
# 4          Launcher 10 2020-11-02 08:00:00+00:00
# ...                ...                       ...
# 30950  СберБанк Онлайн 2016-07-11 17:00:00+00:00
# 30951  СберБанк Онлайн 2016-07-10 16:30:00+00:00
# 30952              ivi 2016-04-24 14:00:00+00:00
# 30953              ivi 2016-04-22 08:00:00+00:00
# 30954              ivi 2015-10-02 22:00:00+00:00
#
#                                                   header  \
# 0                                            Launcher 10
# 1      Readably - RSS | Feedbin, Inoreader and Fever API
# 2                        VK — live chatting & free calls
# 3      Readably - RSS | Feedbin, Inoreader and Fever API
# 4                                            Launcher 10
# ...                                                  ...
# 30950                                    СберБанк Онлайн
# 30951                                    СберБанк Онлайн
# 30952                 ivi - фильмы, сериалы, мультфильмы
# 30953                 ivi - фильмы, сериалы, мультфильмы
# 30954                 ivi - фильмы, сериалы, мультфильмы
#
#                                    app_id
# 0                 com.nfwebdev.launcher10
# 1              com.isaiasmatewos.readably
# 2                   com.vkontakte.android
# 3              com.isaiasmatewos.readably
# 4                 com.nfwebdev.launcher10
# ...                                   ...
# 30950                     СберБанк Онлайн
# 30951                     СберБанк Онлайн
# 30952  ivi - фильмы, сериалы, мультфильмы
# 30953  ivi - фильмы, сериалы, мультфильмы
# 30954  ivi - фильмы, сериалы, мультфильмы
#
# [30955 rows x 4 columns]
