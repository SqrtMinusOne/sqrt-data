# %%
import pandas as pd
import json
import os
import numpy as np
import difflib
import re
import sys

sys.path.append('../..')

from tqdm import tqdm
from collections import deque, namedtuple

from IPython.display import display
from IPython.core.debugger import set_trace

# %% [markdown]
# # Listened log

# %%
DATA = './source/music.json'

FIX_ARTISTS = {
    'Tarja Turunen': 'Tarja',
    'Thomas Bergersen': 'Two Steps from Hell',
    'Томас Бергерсен': 'Two Steps from Hell',
    'Two Steps from Hell & Thomas Bergersen': 'Two Steps from Hell',
    'Tribe': 'Amaranthe',
    'Two Steps From Hell': 'Two Steps from Hell',
    'Two Steps From Hell, Thomas Bergersen': 'Two Steps from Hell',
    'Two Steps From Hell, Nick Phoenix': 'Two Steps from Hell',
    'Андреас Вальдетофт': 'Andreas Waldetoft',
    'Andreas Waltedoft': 'Andreas Waldetoft',
    'Paradox Interactive': 'Andreas Waldetoft',
    'Meyer': 'Andreas Waldetoft',
    'Saxon': 'Sabaton',
    'Visions Of Atlantis': 'Visions of Atlantis',
    'Leaves´ Eyes': 'Leaves\' Eyes',
    'Leaves \' Eyes': 'Leaves\' Eyes',
    'Russell Allen & Anette Olzon': 'Allen/Olzon'
}

FIX_TITLES = {
    'inf': 'infinity'
}

def fix_artist(artist):
    return FIX_ARTISTS.get(artist, artist)

def fix_title(title):
    title = title.lower()
    if not re.match('.*(orchestral|instrumental).*', title):
        title = re.sub(r" ?\([^)]+\)", "", title)
    title = re.sub(r"listened to", "", title)
    title = re.sub(r"(:|~|/).*", "", title)
    title = title.strip()
    return FIX_TITLES.get(title, title)

def check_title(title):
    return "skipped" not in title and "google play music" not in title

with open(DATA, 'r') as f:
    data = json.load(f)

# %%
df = pd.DataFrame(data)
df
# Out:
#                   header                                  title  \
# 0      Google Play Music               Listened to Into the Sun
# 1      Google Play Music               Listened to Sleeping Sun
# 2      Google Play Music  Listened to Kuolleiden jumalten poika
# 3      Google Play Music     Listened to Tähti, hiekka ja varjo
# 4      Google Play Music                 Listened to Isäni ääni
# ...                  ...                                    ...
# 13836  Google Play Music             Listened to Ocean Princess
# 13837  Google Play Music                       Listened to Hurt
# 13838  Google Play Music                 Listened to Dreammaker
# 13839  Google Play Music                 Listened to Starvation
# 13840  Google Play Music                       Listened to Aura
#
#            description                      time             products  \
# 0                Tarja  2020-07-24T19:11:16.641Z  [Google Play Music]
# 1            Nightwish  2020-07-24T18:55:45.200Z  [Google Play Music]
# 2        Marko Hietala  2020-07-24T09:34:55.564Z  [Google Play Music]
# 3        Marko Hietala  2020-07-24T09:30:13.489Z  [Google Play Music]
# 4        Marko Hietala  2020-07-24T09:25:11.939Z  [Google Play Music]
# ...                ...                       ...                  ...
# 13836  Томас Бергерсен  2019-05-12T09:20:50.609Z  [Google Play Music]
# 13837  Томас Бергерсен  2019-05-12T09:17:57.848Z  [Google Play Music]
# 13838  Томас Бергерсен  2019-05-12T09:16:14.505Z  [Google Play Music]
# 13839  Томас Бергерсен  2019-05-12T09:11:56.597Z  [Google Play Music]
# 13840  Томас Бергерсен  2019-05-12T09:07:29.756Z  [Google Play Music]
#
#       subtitles
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ...         ...
# 13836       NaN
# 13837       NaN
# 13838       NaN
# 13839       NaN
# 13840       NaN
#
# [13841 rows x 6 columns]

# %%
df['artist'] = df['description'].apply(fix_artist)
df['title'] = df['title'].apply(fix_title)
df = df[[check_title(t) for t in df.title]]
df = df.reset_index(drop=True)
df = df[['artist', 'title', 'time']]
df
# Out:
#                     artist                      title  \
# 0                    Tarja               into the sun
# 1                Nightwish               sleeping sun
# 2            Marko Hietala  kuolleiden jumalten poika
# 3            Marko Hietala     tähti, hiekka ja varjo
# 4            Marko Hietala                 isäni ääni
# ...                    ...                        ...
# 13600  Two Steps from Hell             ocean princess
# 13601  Two Steps from Hell                       hurt
# 13602  Two Steps from Hell                 dreammaker
# 13603  Two Steps from Hell                 starvation
# 13604  Two Steps from Hell                       aura
#
#                            time
# 0      2020-07-24T19:11:16.641Z
# 1      2020-07-24T18:55:45.200Z
# 2      2020-07-24T09:34:55.564Z
# 3      2020-07-24T09:30:13.489Z
# 4      2020-07-24T09:25:11.939Z
# ...                         ...
# 13600  2019-05-12T09:20:50.609Z
# 13601  2019-05-12T09:17:57.848Z
# 13602  2019-05-12T09:16:14.505Z
# 13603  2019-05-12T09:11:56.597Z
# 13604  2019-05-12T09:07:29.756Z
#
# [13605 rows x 3 columns]

# %% [markdown]
# # Tracks data

# %%
from api import DBConn
from models import Base, MpdSong, SongListened

DBConn()

# %%
data = deque()

with DBConn.get_session() as db:
    for track in db.query(MpdSong).all():
        data.append({
            'title': track.title,
            'id': track.id,
            'artist': track.album_artist,
            'album': track.album
        })

df_t = pd.DataFrame(data)
df_t.title = df_t.title.apply(fix_title)
df_t.artist = df_t.artist.apply(fix_artist)
df_t = df_t.set_index('id')
df_t.head()
# Out:
#                   title         artist                               album
# id
# 1                 enter  After Forever  Remagine: The Album - The Sessions
# 2                  come  After Forever  Remagine: The Album - The Sessions
# 3   boundaries are open  After Forever  Remagine: The Album - The Sessions
# 4        living shields  After Forever  Remagine: The Album - The Sessions
# 5        being everyone  After Forever  Remagine: The Album - The Sessions

# %% [markdown]
# # Join listened with tracks

# %%
tracks_by_name = {}

for track in df_t.itertuples(index=True):
    try:
        tracks_by_name[track.title].append(track)
    except KeyError:
        tracks_by_name[track.title] = [track]
        
track_names = list(tracks_by_name.keys())

# %%
def get_tracks(title, cutoff=0.6):
    try:
        track = tracks_by_name[title]
        return track
    except KeyError:
        pass
    if len(title) > 5:
        try:
            matches = [t for t in track_names if title in t or t in title]
            if len(matches) > 1:
                match = difflib.get_close_matches(title, matches, cutoff=0.4)[0]
            else:
                match = matches[0]
            return tracks_by_name[match]
        except (StopIteration, IndexError):
            pass
    elif "Instrumental" in title:
        title = re.sub('Instrumental', "", title)
        title = re.sub('-', "", title)
        title = title.strip()
        return get_tracks(title, cutoff)
    matches = difflib.get_close_matches(title, track_names, cutoff=cutoff)
    try:
        closest = matches[0]
        return tracks_by_name[closest]
    except IndexError:
        return get_tracks(title, cutoff=0.3)
    return None
    
def pick_track(tracks, track_listened, id_series):
    same_artists = [t for t in tracks if t.artist == track_listened.artist]
    if len(same_artists) == 0:
        same_artists = [t for t in tracks if t.artist == 'nan']
        if len(same_artists) == 0:
            return None
    if len(same_artists) == 1:
        return same_artists[0]
    by_album = {t.album: t for t in same_artists}
    try:
        previous_track = df_t.loc[id_series[len(id_series) - 1]]
        if previous_track.artist == track_listened.artist:
            return by_album[previous_track.album]
    except (KeyError, TypeError):
        pass
    return same_artists[0]
    
id_series = deque()
not_matched = []
NotMatched = namedtuple('NotMatched', ['track', 'candidates'])

for track_listened in tqdm(list(df.itertuples(index=True))):
    tracks = get_tracks(track_listened.title)
    if tracks is None:
        id_series.append(None)
        not_matched.append(NotMatched(track_listened))
        continue
    track = pick_track(tracks, track_listened, id_series)
    if track is None:
        id_series.append(None)
        not_matched.append(NotMatched(track_listened, tracks))
        continue
    id_series.append(track.Index)
# Out:
# 100%|██████████| 13605/13605 [00:05<00:00, 2660.52it/s]

# %%
df['id'] = id_series
df_nm = pd.DataFrame([t.track for t in not_matched])
# display(len(id_series))

with pd.option_context('display.max_rows', 1000):
    display(df_nm)
# Out:
#      Index             artist                                title  \
# 0     1145          Nightwish                            elvenpath
# 1     2644         Blackbriar                madwoman in the attic
# 2     2645         Blackbriar                   beautiful delirium
# 3     2646         Blackbriar                       mortal remains
# 4     2647         Blackbriar                   the rooster's crow
# 5     4937         Blackbriar                   beautiful delirium
# 6     5522         Blackbriar                   beautiful delirium
# 7     5787         Blackbriar                   beautiful delirium
# 8     5799       Leaves' Eyes                            to france
# 9     5800       Leaves' Eyes                            krakevisa
# 10    5801       Leaves' Eyes                         velvet heart
# 11    5802       Leaves' Eyes                                étaín
# 12    5803       Leaves' Eyes                  spirits' masquerade
# 13    5818       Leaves' Eyes                        the holy bond
# 14    5819       Leaves' Eyes                           morgenland
# 15    5820       Leaves' Eyes                             ragnarok
# 16    5821       Leaves' Eyes                           northbound
# 17    5822       Leaves' Eyes                           irish rain
# 18    5823       Leaves' Eyes                    through our veins
# 19    5824       Leaves' Eyes                     scarborough fair
# 20    5825       Leaves' Eyes                 take the devil in me
# 21    5826       Leaves' Eyes                       emerald island
# 22    5827       Leaves' Eyes                           my destiny
# 23    5828       Leaves' Eyes                                njord
# 24    5864       Leaves' Eyes                             ragnarok
# 25    5865       Leaves' Eyes                           northbound
# 26    5866       Leaves' Eyes                           irish rain
# 27    5867       Leaves' Eyes                    through our veins
# 28    5868       Leaves' Eyes                     scarborough fair
# 29    5869       Leaves' Eyes                 take the devil in me
# 30    5870       Leaves' Eyes                       emerald island
# 31    5871       Leaves' Eyes                           my destiny
# 32    5872       Leaves' Eyes                                njord
# 33    5894         Blackbriar                       mortal remains
# 34    5895         Blackbriar                   the rooster's crow
# 35    5896         Blackbriar                   beautiful delirium
# 36    5935         Blackbriar                       mortal remains
# 37    5936         Blackbriar                   beautiful delirium
# 38    6040         Blackbriar                madwoman in the attic
# 39    6041         Blackbriar                   beautiful delirium
# 40    6085         Blackbriar                madwoman in the attic
# 41    6086         Blackbriar                   beautiful delirium
# 42    6087         Blackbriar                       mortal remains
# 43    6088         Blackbriar                   the rooster's crow
# 44    6102         Blackbriar  until eternity (orchestral version)
# 45    6103         Blackbriar                madwoman in the attic
# 46    6104         Blackbriar                   beautiful delirium
# 47    6105         Blackbriar                       mortal remains
# 48    6106         Blackbriar                   the rooster's crow
# 49    6157         Blackbriar  until eternity (orchestral version)
# 50    6158         Blackbriar                madwoman in the attic
# 51    6159         Blackbriar                   beautiful delirium
# 52    6201         Blackbriar  until eternity (orchestral version)
# 53    6202         Blackbriar                madwoman in the attic
